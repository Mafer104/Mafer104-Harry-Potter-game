# %%
#Author: Maria Fernanda Pernillo

"""Description of the game:This game is inspired in Harry Potter and the Goblet of Fire. 
The player would be assigned to a house randomly, with the help of the Sorting Hat. 
The objective of the game is to collect the golden egg that a dragon guards, 
the player must carefully select the spell that will help him defeat it!
The game consists of 3 main paths, in the first one the player must select 
which house he belongs to, since the dragons are assigned based on that. 
After knowing which dragon, he or she would face, the player has the option 
#to choose to know more about the breed of the assigned creature or continue.
Then they would face the dragon by selecting a spell, not all of them work on big creatures!"""
#Bugs: spaces, maybe some formating, the player has to choose what house he was assigned to manually,the player gets back to intro instead of proceding to the main paths. 
 





import sys
import time 
import random 

a = 2 
b = 0.040
c = 0.01

#After deciding to start, defining the intro in order for the game to continue 
def intro ():
    print()
    time.sleep(b)
    preasign =("First you will be assigned into a house. The sorting hat will help us decide")
    for character in preasign:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)  
        
        
#Sorting hat appears and randomly assigns a house to the player. The options are Slythering, Gryffindor and Hufflepuf
    time.sleep (c)
    print(f'''
         /:\ 
        /;:.\ 
       //;:. \ \t
      ///;:.. \ \t
__--"////;:... \"--__
--__ "--_____--"   __--
  """--_______--""" 
       ''')
#Sorting hat speaks and interacts with the player
    hat1 = '"Well, hello there! What is your name?"\n'
    for character in hat1:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    name = input()
    hat2 = (f'"{name}! That is a great name, it means one who is brave and courageous... let me think where you belong..."\n  "you definitelly belong to: ')
    for character in hat2:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
            
#Randomly assigns the house to the player
    houses = ["Slythering", "Gryffindor", "Hufflepuf"]
    print()
    for house in range (1):
        print(random.choice(houses))
        print()
#The instructions of the game, choose a spell to collect the egg
    instructions = (f'''Great! is time to proceed to the task! Each house would be assigned to a dragon, each of which has been given a golden egg.Your task is simple: Choose the right spell to distract the dragon and collect the egg before you get burned!''')
    for character in instructions:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    print('''
                
   \***__          ___                                             
    |   *****\_   --/*\-___                                          
    /_        (_  ./ ,/----'                                         
      \__      (_./  /                                        
         \__         \___---^__                                       
          _/_              __/                                      
    |   _/  __/)\"\ _____  \                                    
    |\__/  /   ^ ^    \____/                                   
    \___--"            \___)                                 
                        
        ''')  
    print()
    time.sleep(b)
#Player has to choose which house he/she was assigned to
    houseType = input("""Select which house of Hogwarts you where assigned to:
                     a) Glyffindor
                     b) Slytherin
                     c) Hufflepuff\n""") 
    for character in houseType:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    print()
    if houseType == "a" or houseType =="glyffindor" or houseType == "Glyffindor":
        print()
        time.sleep(b)
        path1()
    elif houseType == "b" or houseType == "slytherin" or houseType == "Slytherin":
        print()
        time.sleep(b)
        path2()
    elif houseType == "c" or houseType == "hufflepuff" or houseType == "Hufflepuff":
        print()
        time.sleep(b)
        path3()

#Path 1 - Glyffindor- the player gets to know which dragon he/she will fight as well as the option to know more about it
def path1():
    print()
    glyffindor_welcome = ("Congratulations, the type of dragon you will fight is a Hungarian Horntail Dragon")
    for character in glyffindor_welcome:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    print()
    dragonBreed = input("Would you like to know more about this creature before you fight it? (Y/N) ")
    if dragonBreed == 'n'or startGame == 'N':
        time.sleep(a)
        print("Wow, brave Wizard, Good luck")
        time.sleep(b)
        path1b()
    elif dragonBreed == 'y' or dragonBreed == 'Y':
        time.sleep(a)
        dragonDescription = ("""The Hungarian Horntail has black scales and is lizard-like in appearance! \n Supposedly is the most dangerous of all dragon breeds! 
        Good luck, you'll need it!""")
        for character in dragonDescription:
            sys.stdout.write(character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(b)
        path1a()
        
        
#Give the player the option to continue or quit        
def path1a():
    question =input("""After knowing this... are you sure you want to cath the egg? 
                     1) Nah, I rather drink a butter beer
                     2) Yes! I am ready to fight it!
                     3) Help me Harry!\n
    """)
    if question == "1":
        print("oh, thats to bad! Enjoy the beer, we recommend the one sold at the Three Broomsticks! Or...")
        restart()
    elif question == "2":
        print("Great! You are a brave wizard!")
        path1b()
    elif question =="3":
        print("Sorry he is fighting Voldermort  ")
        restart()
     
        
#time to fight the dragon in path 1
def path1b():
    chose_spell = ("Is time to fight it, choose carefully which spell you will use to distract the dragon and collect the egg... ")
    for character in chose_spell:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    print()
    spell = input ("""
                     a) Draconifors
                     b) Wingardium Leviosa
                     c) Avada Kadabra\n""")
    for character in chose_spell:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b) 
    if spell == "a"or spell == "Draconifors" or spell == "draconifors":
        print()
        print("Good job! the dragon was scared and you caught the egg!")
        time.sleep(b)
        restart()
    elif spell == "b" or spell =="Wingardium Leviosa" or spell =="wingardium leviosa":
        print(f'''ohh nooo that spell works only in little things... you lose
        GAME OVER''')
        print( ('*'*70))
        time.sleep(b)
        restart()
    elif spell =="c" or spell == "Avada Kadabra" or spell == "avada kadabra":
        print("The most letal spell, even dragons fear it! Well done! You collect the egg")
        time.sleep(b)
        restart()

        
#Path 2- Slytherin - the player gets to know which dragon he/she will fight as well as the option to know more about it     
def path2():
    print()
    sly_welcome = ("Congratulations, the type of dragon you will fight is a Common Welsh Green Dragon")
    for character in sly_welcome:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    dragonBreed = input("Would you like to know more about it before you fight it? (Y/N) ")
    if dragonBreed == 'n'or startGame == 'N':
        time.sleep(b)
        print("Wow, brave Wizard, Good luck!")
        time.sleep(c)
        path2b()
    elif dragonBreed == 'y' or dragonBreed == 'Y':
        time.sleep(a)
        dragonDescription2 = ("""Is a dragon native to Wales. It nests in the higher mountain regions where a reservation has been set up for it. It is a green dragon with a distinctive, musical roar.
        Good luck, careful with your ears!""")
        for character in dragonDescription2:
            sys.stdout.write(character)
            sys.stdout.flush()
            time.sleep(b)
        print()
        time.sleep(b)
        path2a()

    
#Give the player the option to continue or quit   
def path2a():
    question = input("""After knowing this... are you sure you want to cath the egg? 
                     1) Nah, I rather drink a butter beer
                     2) Yes! I am ready to fight it!
                     3) Help me Harry!\n
    """)
    if question == "1":
        print("oh, thats to bad! Enjoy the beer, we recommend the one sold at the Three Broomsticks! Or...")
        restart()
    elif question == "2":
        print("Great! You are a brave wizard!")
        path2b()
    elif question =="3":
        print("Sorry he is fighting Voldermort  ")
        restart()
     
    
#time to fight the dragon in path 2
def path2b():
    print()
    chose_spell2 =("Is time to fight it, choose carefully which spell you will use to distract the dragon and collect the egg... ")
    for character in chose_spell2:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    spell = input ("""
                     a) Draconifors
                     b) Wingardium Leviosa
                     c) Avada Kadabra\n""")
    for character in spell:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    if spell == "a"or spell == "Draconifors" or spell == "draconifors":
        print()
        print("Good job! the dragon was scared and you cath the egg!")
        restart()
    elif spell == "b" or spell =="Wingardium Leviosa" or spell =="wingardium leviosa":
        print(f'''ohh nooo that spell works only in little things... you lose
        GAME OVER''')
        print( ('*'*70))
        time.sleep(b)
        restart()
    elif spell =="c" or spell == "Avada Kadabra" or spell == "avada kadabra":
        print("The most letal spell, even dragons fear it! Well done! You collect the egg!")
        time.sleep(b)
        restart()
    

#Path 3 - Hufflepuff - the player gets to know which dragon he/she will fight as well as the option to know more about it   
def path3():
    print()
    huf_welcome= ("Congratulations, the type of dragon you will fight is a Chinese Fireball Dragon" )
    for character in huf_welcome:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    dragonBreed = input("Would you like to know more about it before you fight it? (Y/N)\n")
    if dragonBreed == 'n'or startGame == 'N':
        time.sleep(a)
        print("Wow, brave Wizard, Good luck!")
        time.sleep(c)
        path3b()
    elif dragonBreed == 'y' or dragonBreed == 'Y':
        time.sleep(a)
        dragonDescription3 = ("""Dragon native of China. It is a brilliant red and gold dragon, named for the rounded balls of flame that shot from its nostrils.")
        Good luck, try not to burn yourself!""")
        for character in dragonDescription3:
            sys.stdout.write(character)
            sys.stdout.flush()
            time.sleep(b)
        print()
        time.sleep(b)
        path3a()
    
    
#Give the player the option to continue or quit        
def path3a():
    question = input("""After knowing this... are you sure you want to cath the egg? 
                     1) Nah, I rather drink a butter beer
                     2) Yes! I am ready to fight it!
                     3) Help me Harry!\n
    """)
    if question == "1":
        print("oh, thats to bad! Enjoy the beer, we recommend the one sold at the Three Broomsticks! Or...")
        restart()
    elif question == "2":
        print("Great! You are a brave wizard!")
        path3b()
    elif question =="3":
        print("Sorry he is fighting Voldermort  ")
        restart()
        

#time to fight the dragon in path 3
def path3b():
    print()
    chose_spell3 = ("Is time to fight it, choose carefully which spell you will use to distract the dragon and collect the egg...  ")
    for character in chose_spell3:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    print()
    spell = input ("""
                     a) Draconifors
                     b) Wingardium Leviosa
                     c) Avada Kadabra\n""")
    for character in spell:
        sys.stdout.write(character)
        sys.stdout.flush()
        time.sleep(b)
    if spell == "a"or spell == "Draconifors" or spell == "draconifors":
        print()
        print("Good job! the dragon was scared and you caught the egg!")
        print( ('*'*70))
        time.sleep(b)
        restart()
    elif spell == "b" or spell =="Wingardium Leviosa" or spell =="wingardium leviosa":
        print(f'''ohh nooo that spell works only in little things... you lose
        GAME OVER''')
        print( ('*'*70))
        restart()
    elif spell =="c" or spell == "Avada Kadabra" or spell == "avada kadabra":
        print("The most letal spell,even dragons fear it! Well done! You collect the egg!")
        print( ('*'*70))
        time.sleep (b)
        restart()
        
        
#Restart the game function        
def restart():
    replay = input("Would you like to try again? (Y/N)\n")
    if replay == "yes" or replay == "Yes" or replay == "y":
        intro()
    elif replay == "no" or replay == "No" or replay == "n":
        print("Thanks for playing wizard, see you next time!")


#Introduction to the game
intro1 = f"""Welcome to the Annual Wizard Tournament at Hogwarts! 
It is the time of the year where wizards get the chance to prove their courage!
These contests are not for the faint-hearted! Be ready to fight all kinds of strange creatures!"""
for character in intro1:
    sys.stdout.write(character)
    sys.stdout.flush()
    time.sleep(b)
    
    
#Player can decide to start game or quit
startGame = input(f'This year the first contest involves some magical creatures!\n Are you ready to start? (Y/N)\n')
if startGame == 'n'or startGame == 'N':
    print("Are you sure?")
    restart()
elif startGame == 'y'or startGame =='Y':
    intro()
# Out:
# Welcome to the Annual Wizard Tournament at Hogwarts!
# It is the time of the year where wizards get the chance to prove their courage!
# These contests are not for the faint-hearted! Be ready to fight all kinds of strange creatures!
# This year the first contest involves some magical creatures!	 Are you ready to start? (Y/N)
# y
#
# First you will be assigned into a house. The sorting hat will help us decide
#          /:\
#         /;:.\
#        //;:. \
#       ///;:.. \
# __--"////;:... "--__
# --__ "--_____--"   __--
#   """--_______--"""
#
# "Well, hello there! What is your name?"
# mo
# "mo! That is a great name, it means one who is brave and courageous... let me think where you belong..."
#   "you definitelly belong to:
# Slythering
#
# Great! is time to proceed to the task! Each house would be assigned a different dragon, each of which has been given a golden egg.
#     Your task is simple: Collect the egg before you get burned!
#
#    \***__          ___
# ...

# %%
# Out:
# ohh nooo that spell works only in little things... you lose
#         GAME OVER
# **********************************************************************
